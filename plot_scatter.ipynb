# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
a=np.array([[1,2],[2,3]])

# %%
plt.scatter(a[:,0], a[:,1],c='b')

# %%
from matplotlib.pyplot import plot

# %%
a=1
b=3
x1=1
x2=3
y1=a*x1+b
y2=a*x2+b
plot([x1,x2],[y1,y2],'b')
