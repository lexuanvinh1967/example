# %%
import numpy as np
X1= np.random.randint(1,50,size=(10,2))
X2= np.random.randint(50,100,size=(10,2))
X=np.concatenate((X1,X2),axis=0)
y1=np.random.randint(100,200,size=(10))
y2=np.random.randint(200,300,size=(10))
y=np.concatenate((y1,y2), axis=0)
y
# Out:
# array([110, 132, 192, 174, 147, 170, 188, 100, 156, 197, 280, 296, 257,
#        225, 233, 226, 218, 296, 228, 213])

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
model = KNeighborsRegressor()
model.fit(X,y)
# Out:
# KNeighborsRegressor()

# %%
y1=model.predict(X)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# Creating figure
fig = plt.figure()
ax=plt.axes(projection="3d")
# Creating plot
ax.scatter3D(X[:,0],X[:,1],y, color="red")
ax.scatter3D(X[:,0],X[:,1],y1, color="blue")
# Show plot
plt.show()

# %%
fig = plt.figure()
ax=plt.axes(projection="3d")
# Creating plot
y = X[:,0] + X[:,1]
ax.plot_surface(X[:,0],X[:,1],y)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-14914bec860e> in <module>
#       3 # Creating plot
#       4 y = X[:,0] + X[:,1]
# ----> 5 ax.plot_surface(X[:,0],X[:,1],y)
#       6
#       7 # Show plot
#
# ~\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1554
#    1555         if Z.ndim != 2:
# -> 1556             raise ValueError("Argument Z must be 2-dimensional.")
#    1557         if np.any(np.isnan(Z)):
#    1558             cbook._warn_external(
#
# ValueError: Argument Z must be 2-dimensional.
