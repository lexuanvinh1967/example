# %%
import sklearn.metrics as metrics
from keras.models import Sequential
from keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
history1= np.load('E:/anhECG/my_history.npy',allow_pickle='True').item()
print(np.average(history1['accuracy']))
# Out:
# 0.9577895522117614

# %%
print(history1['loss'])
# Out:
# [1.3319766521453857, 0.16210639476776123, 0.16893406212329865, 0.15879622101783752, 0.17809049785137177, 0.15629827976226807, 0.15664878487586975, 0.16210903227329254, 0.17141461372375488, 0.18531803786754608]

# %%
a=np.array([10])
b=np.concatenate(a,history1['loss'])
plt.plot(b)


plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-727e28202063> in <module>
#       1 a=np.array([10])
# ----> 2 b=np.concatenate(a,history1['loss'])
#       3 plt.plot(b)
#       4
#       5
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: 'list' object cannot be interpreted as an integer

# %%
# summarize history for accuracy
plt.plot(history1['accuracy'])
plt.plot(history1['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history1['loss'])
plt.plot(history1['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
import pickle
history1= np.load('my_history.npy',allow_pickle='True').item()
print(np.average(history1['val_accuracy']))
# Out:
# 0.6977690360943476

# %%
# summarize history for accuracy
plt.plot(history1['accuracy'])
plt.plot(history1['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history1['loss'])
plt.plot(history1['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
yhat = model.predict(X)
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001C87FC37510> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x000001C87FC37510> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
import sklearn.metrics as metrics
yhat=np.round(yhat)
metrics.confusion_matrix(yhat,Y)
# Out:
# array([[436, 119],
#        [ 64, 149]], dtype=int64)
